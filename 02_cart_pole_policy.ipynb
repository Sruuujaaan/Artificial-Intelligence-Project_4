# %% [markdown]
# Observed features are expanded with a random transform to ensure linear separability,action selection is by dot product of an expanded observation with a weight vector, a queued history of recent observations is shuffled and replayed to update the output weights, output weights are updated at the end of each incomplete episode by LMS update,the target outputs for the LMS algorithm are the means of the past outputs,output weights are maintained at a fixed norm for
# regularization.

# %%
import gym
from numpy import *
from numpy.random import uniform,normal
from numpy.linalg import norm
from random import shuffle
from collections import deque
from statistics import mean

# %%
env = gym.make('CartPole-v1')

# %% [markdown]
# Hyperparameters

# %%
alpha = 2.0e-1              # Learning rate
maxEpisodes = 1000          # Episodes for which I am running the agent
maxTimeSteps = 500          # Maximum number of steps per episode
normVar = 0.5               # Used for Scaling
maxHistory = 5000           # Maximum number of recent observations for replay
successfulEpisodes = 100    # Cartpole is solved when average reward > 195 for 'solvedEpisodes'
episodeLength = 500         # The target for CartPole-v1

# %% [markdown]
# Observations Transform

# %%
inputLength = 4             # Length of an observation vector
expansionFactor = 30
expandedLength = expansionFactor*inputLength

# %% [markdown]
# Feature transform with fixed random weights.

# %%
V = normal(scale=1.0, size=(expandedLength, inputLength))

# %% [markdown]
# Output weights, randomly initialized.

# %%
weight = uniform(low=-1.0, high=1.0, size=expandedLength)
weight *= normVar / norm(weight)         # Fix the norm of the output weights to 'fixedNorm'.

# %% [markdown]
# Used Least mean squares (LMS) algorithm

# %%
def AgentCartPole(alpha, W, V):
    observationHistory = deque([], maxHistory)
    totalRewardHistory = deque([], successfulEpisodes)
    positiveOutput = deque([0], maxHistory)
    negativeOutput = deque([0], maxHistory)
    counter =0
    for episode in range(maxEpisodes):
        observation = env.reset()
        observationHistory.append(observation)
        totalReward = 0
        for t in range(1,maxTimeSteps+1):
            env.render()
            out = dot(tanh(dot(V,observation)), W)
            if out < 0:
                negativeOutput.append(out)
                action = 0
            else:
                positiveOutput.append(out)
                action = 1
            observation, reward, done, info = env.step(action)
            observationHistory.append(observation)
            totalReward += reward
            if done:
                totalRewardHistory.append(totalReward)
                if t < episodeLength:
                    # Replay shuffled past observations using the, latest weights.
                    # Use the means of past outputs as, (Least Mean Squares) algorithm target outputs.
                    mn = mean(negativeOutput)
                    mp = mean(positiveOutput)
                    shuffle(observationHistory)
                    for obs in observationHistory:
                        h = tanh(dot(V, obs))       # Transform the observation
                        out = dot(h, W)
                        if out < 0:
                            e = mn - out
                        else:
                            e = mp - out
                        W += alpha * e * h          # Least Mean Squares update
                        W *= normVar / norm(W)      # Keep the weights at fixed norm

                avgReward = sum(totalRewardHistory) / successfulEpisodes
                print(f"Episode_Number:{episode:2d} TotalR:{totalReward:7.3f}  Average_Reward:{avgReward:7.3f}  len(H):{len(observationHistory):7.3f}  W:{W[:2]}")
                if avgReward >= 195:
                    counter += 1
                else:
                    counter = 0
                if counter > 100:
                    print("FINISHED")
                    return
                break

# %%
AgentCartPole(alpha, weight, V)
env.close()
# Out:
# Episode_Number: 0 TotalR:  9.000  Average_Reward:  0.090  len(H): 10.000  W:[-0.05227981  0.02990159]
# Episode_Number: 1 TotalR: 10.000  Average_Reward:  0.190  len(H): 21.000  W:[ 0.05326689 -0.02985863]
# Episode_Number: 2 TotalR:205.000  Average_Reward:  2.240  len(H):227.000  W:[ 0.03939755 -0.01416592]
# Episode_Number: 3 TotalR:159.000  Average_Reward:  3.830  len(H):387.000  W:[-0.0679574   0.04400136]
# Episode_Number: 4 TotalR:  8.000  Average_Reward:  3.910  len(H):396.000  W:[ 0.05474901 -0.0135555 ]
# Episode_Number: 5 TotalR:169.000  Average_Reward:  5.600  len(H):566.000  W:[ 0.07314542 -0.0192789 ]
# Episode_Number: 6 TotalR: 82.000  Average_Reward:  6.420  len(H):649.000  W:[-0.03884899  0.00158764]
# Episode_Number: 7 TotalR: 11.000  Average_Reward:  6.530  len(H):661.000  W:[ 0.00961585 -0.00552221]
# Episode_Number: 8 TotalR:  9.000  Average_Reward:  6.620  len(H):671.000  W:[-0.02508117  0.03646298]
# Episode_Number: 9 TotalR: 10.000  Average_Reward:  6.720  len(H):682.000  W:[ 0.0527739  -0.02058969]
# Episode_Number:10 TotalR:192.000  Average_Reward:  8.640  len(H):875.000  W:[-0.00508295 -0.01151247]
# Episode_Number:11 TotalR: 10.000  Average_Reward:  8.740  len(H):886.000  W:[0.03173859 0.0004996 ]
# Episode_Number:12 TotalR: 74.000  Average_Reward:  9.480  len(H):961.000  W:[ 0.05735689 -0.00196368]
# Episode_Number:13 TotalR:193.000  Average_Reward: 11.410  len(H):1155.000  W:[-0.00293263  0.02163931]
# Episode_Number:14 TotalR: 28.000  Average_Reward: 11.690  len(H):1184.000  W:[-0.02803589 -0.02599425]
# Episode_Number:15 TotalR:  9.000  Average_Reward: 11.780  len(H):1194.000  W:[ 0.00308418 -0.05228194]
# Episode_Number:16 TotalR: 38.000  Average_Reward: 12.160  len(H):1233.000  W:[-0.03773879 -0.00502502]
# Episode_Number:17 TotalR: 10.000  Average_Reward: 12.260  len(H):1244.000  W:[0.0294206  0.03891456]
# Episode_Number:18 TotalR: 71.000  Average_Reward: 12.970  len(H):1316.000  W:[-0.0407727  -0.02638606]
# Episode_Number:19 TotalR:  8.000  Average_Reward: 13.050  len(H):1325.000  W:[-0.04484736  0.00296416]
# Episode_Number:20 TotalR:  9.000  Average_Reward: 13.140  len(H):1335.000  W:[ 0.01817958 -0.02008754]
# Episode_Number:21 TotalR: 71.000  Average_Reward: 13.850  len(H):1407.000  W:[ 0.04239713 -0.0180572 ]
# Episode_Number:22 TotalR:272.000  Average_Reward: 16.570  len(H):1680.000  W:[-0.00937043  0.0124249 ]
# Episode_Number:23 TotalR: 43.000  Average_Reward: 17.000  len(H):1724.000  W:[ 0.00026657 -0.0147985 ]
# Episode_Number:24 TotalR: 11.000  Average_Reward: 17.110  len(H):1736.000  W:[-0.04338821 -0.02320742]
# Episode_Number:25 TotalR:  8.000  Average_Reward: 17.190  len(H):1745.000  W:[-0.00883897  0.00797569]
# Episode_Number:26 TotalR: 22.000  Average_Reward: 17.410  len(H):1768.000  W:[ 0.05286778 -0.03791347]
# Episode_Number:27 TotalR: 45.000  Average_Reward: 17.860  len(H):1814.000  W:[ 0.05147669 -0.01556907]
# Episode_Number:28 TotalR: 54.000  Average_Reward: 18.400  len(H):1869.000  W:[-0.01057548 -0.02737991]
# Episode_Number:29 TotalR: 10.000  Average_Reward: 18.500  len(H):1880.000  W:[-0.0242037   0.02628447]
# Episode_Number:30 TotalR:  9.000  Average_Reward: 18.590  len(H):1890.000  W:[ 0.06091204 -0.01899159]
# Episode_Number:31 TotalR: 90.000  Average_Reward: 19.490  len(H):1981.000  W:[-0.03396196  0.01020306]
# Episode_Number:32 TotalR: 10.000  Average_Reward: 19.590  len(H):1992.000  W:[-0.04251775  0.03759295]
# Episode_Number:33 TotalR:  8.000  Average_Reward: 19.670  len(H):2001.000  W:[ 0.05378797 -0.00300157]
# Episode_Number:34 TotalR: 86.000  Average_Reward: 20.530  len(H):2088.000  W:[-0.00220528  0.04036882]
# Episode_Number:35 TotalR:  9.000  Average_Reward: 20.620  len(H):2098.000  W:[ 0.03644277 -0.04834542]
# Episode_Number:36 TotalR: 55.000  Average_Reward: 21.170  len(H):2154.000  W:[ 0.05167773 -0.0352385 ]
# Episode_Number:37 TotalR: 94.000  Average_Reward: 22.110  len(H):2249.000  W:[ 0.03325311 -0.00119693]
# Episode_Number:38 TotalR: 40.000  Average_Reward: 22.510  len(H):2290.000  W:[-0.04081444 -0.01208732]
# Episode_Number:39 TotalR:  8.000  Average_Reward: 22.590  len(H):2299.000  W:[ 0.01434451 -0.02729249]
# Episode_Number:40 TotalR: 27.000  Average_Reward: 22.860  len(H):2327.000  W:[-0.04157963 -0.00088443]
# Episode_Number:41 TotalR:  9.000  Average_Reward: 22.950  len(H):2337.000  W:[-0.02157813  0.0134019 ]
# Episode_Number:42 TotalR: 10.000  Average_Reward: 23.050  len(H):2348.000  W:[ 0.05443121 -0.02995169]
# Episode_Number:43 TotalR: 88.000  Average_Reward: 23.930  len(H):2437.000  W:[-0.06937065  0.00328669]
# Episode_Number:44 TotalR:  9.000  Average_Reward: 24.020  len(H):2447.000  W:[-0.01674066  0.00146934]
# Episode_Number:45 TotalR: 33.000  Average_Reward: 24.350  len(H):2481.000  W:[-0.05891314  0.01818328]
# Episode_Number:46 TotalR: 10.000  Average_Reward: 24.450  len(H):2492.000  W:[ 0.07358982 -0.04362316]
# Episode_Number:47 TotalR: 40.000  Average_Reward: 24.850  len(H):2533.000  W:[ 0.01121815 -0.00250031]
# Episode_Number:48 TotalR:  9.000  Average_Reward: 24.940  len(H):2543.000  W:[-0.06538265  0.03848348]
# Episode_Number:49 TotalR:  8.000  Average_Reward: 25.020  len(H):2552.000  W:[-0.00329874  0.03343263]
# Episode_Number:50 TotalR: 37.000  Average_Reward: 25.390  len(H):2590.000  W:[ 0.01259882 -0.04264473]
# Episode_Number:51 TotalR: 15.000  Average_Reward: 25.540  len(H):2606.000  W:[-0.04161561  0.01540566]
# Episode_Number:52 TotalR: 10.000  Average_Reward: 25.640  len(H):2617.000  W:[-0.02576708  0.01268676]
# Episode_Number:53 TotalR: 10.000  Average_Reward: 25.740  len(H):2628.000  W:[ 0.00190973 -0.04249994]
# Episode_Number:54 TotalR:  9.000  Average_Reward: 25.830  len(H):2638.000  W:[-0.04963038  0.03350786]
# Episode_Number:55 TotalR: 10.000  Average_Reward: 25.930  len(H):2649.000  W:[-0.05409078  0.02818958]
# Episode_Number:56 TotalR:  9.000  Average_Reward: 26.020  len(H):2659.000  W:[0.00792597 0.04242824]
# Episode_Number:57 TotalR: 51.000  Average_Reward: 26.530  len(H):2711.000  W:[0.03282699 0.00425692]
# Episode_Number:58 TotalR: 73.000  Average_Reward: 27.260  len(H):2785.000  W:[-0.07663809  0.00066617]
# Episode_Number:59 TotalR:  9.000  Average_Reward: 27.350  len(H):2795.000  W:[0.05561756 0.00992218]
# Episode_Number:60 TotalR: 46.000  Average_Reward: 27.810  len(H):2842.000  W:[-0.02442573 -0.03299915]
# Episode_Number:61 TotalR:  9.000  Average_Reward: 27.900  len(H):2852.000  W:[-0.05154943  0.02936573]
# Episode_Number:62 TotalR: 10.000  Average_Reward: 28.000  len(H):2863.000  W:[ 0.05470966 -0.00940766]
# Episode_Number:63 TotalR:133.000  Average_Reward: 29.330  len(H):2997.000  W:[ 0.04766248 -0.04022829]
# Episode_Number:64 TotalR: 51.000  Average_Reward: 29.840  len(H):3049.000  W:[-0.0519063   0.03964494]
# Episode_Number:65 TotalR: 10.000  Average_Reward: 29.940  len(H):3060.000  W:[-0.00538256  0.0056578 ]
# Episode_Number:66 TotalR: 10.000  Average_Reward: 30.040  len(H):3071.000  W:[ 0.04789208 -0.00010199]
# Episode_Number:67 TotalR:171.000  Average_Reward: 31.750  len(H):3243.000  W:[ 0.05691352 -0.02667656]
# Episode_Number:68 TotalR:166.000  Average_Reward: 33.410  len(H):3410.000  W:[-0.03734418  0.00626626]
# Episode_Number:69 TotalR: 10.000  Average_Reward: 33.510  len(H):3421.000  W:[-0.02502952  0.01122608]
# Episode_Number:70 TotalR: 14.000  Average_Reward: 33.650  len(H):3436.000  W:[-0.027703    0.02517048]
# Episode_Number:71 TotalR: 10.000  Average_Reward: 33.750  len(H):3447.000  W:[0.03383932 0.0104416 ]
# Episode_Number:72 TotalR:500.000  Average_Reward: 38.750  len(H):3948.000  W:[0.03383932 0.0104416 ]
# Episode_Number:73 TotalR:406.000  Average_Reward: 42.810  len(H):4355.000  W:[-0.04717159  0.00985198]
# Episode_Number:74 TotalR: 10.000  Average_Reward: 42.910  len(H):4366.000  W:[ 0.05346905 -0.03358454]
# Episode_Number:75 TotalR: 48.000  Average_Reward: 43.390  len(H):4415.000  W:[-0.02224711  0.0281915 ]
# Episode_Number:76 TotalR:  9.000  Average_Reward: 43.480  len(H):4425.000  W:[ 0.03941735 -0.03235517]
# Episode_Number:77 TotalR: 89.000  Average_Reward: 44.370  len(H):4515.000  W:[-0.01600103  0.04007877]
# Episode_Number:78 TotalR:112.000  Average_Reward: 45.490  len(H):4628.000  W:[-0.0557574   0.01399372]
# Episode_Number:79 TotalR:  8.000  Average_Reward: 45.570  len(H):4637.000  W:[-0.03826162  0.04317233]
# Episode_Number:80 TotalR: 10.000  Average_Reward: 45.670  len(H):4648.000  W:[-0.0197872  -0.03916977]
# Episode_Number:81 TotalR:  8.000  Average_Reward: 45.750  len(H):4657.000  W:[-0.03810094  0.04370863]
# Episode_Number:82 TotalR: 10.000  Average_Reward: 45.850  len(H):4668.000  W:[ 0.0706749  -0.01436432]
# Episode_Number:83 TotalR:134.000  Average_Reward: 47.190  len(H):4803.000  W:[ 0.00080289 -0.01991192]
# Episode_Number:84 TotalR:  9.000  Average_Reward: 47.280  len(H):4813.000  W:[ 0.02572658 -0.022447  ]
# Episode_Number:85 TotalR: 44.000  Average_Reward: 47.720  len(H):4858.000  W:[ 0.06758646 -0.02299352]
# Episode_Number:86 TotalR: 66.000  Average_Reward: 48.380  len(H):4925.000  W:[ 0.06081247 -0.02612517]
# Episode_Number:87 TotalR: 71.000  Average_Reward: 49.090  len(H):4997.000  W:[0.01640827 0.03019734]
# Episode_Number:88 TotalR:204.000  Average_Reward: 51.130  len(H):5000.000  W:[ 0.06611284 -0.00661707]
# Episode_Number:89 TotalR: 34.000  Average_Reward: 51.470  len(H):5000.000  W:[0.00851547 0.01192267]
# Episode_Number:90 TotalR: 61.000  Average_Reward: 52.080  len(H):5000.000  W:[ 0.06685547 -0.00297907]
# Episode_Number:91 TotalR:101.000  Average_Reward: 53.090  len(H):5000.000  W:[ 0.00459368 -0.04372519]
# Episode_Number:92 TotalR: 12.000  Average_Reward: 53.210  len(H):5000.000  W:[-0.05876785  0.00082933]
# Episode_Number:93 TotalR:  9.000  Average_Reward: 53.300  len(H):5000.000  W:[-0.03095267  0.01908696]
# Episode_Number:94 TotalR: 14.000  Average_Reward: 53.440  len(H):5000.000  W:[ 0.06260526 -0.0360828 ]
# Episode_Number:95 TotalR: 45.000  Average_Reward: 53.890  len(H):5000.000  W:[ 0.00671837 -0.01859889]
# Episode_Number:96 TotalR:232.000  Average_Reward: 56.210  len(H):5000.000  W:[ 0.05506915 -0.0397298 ]
# Episode_Number:97 TotalR:148.000  Average_Reward: 57.690  len(H):5000.000  W:[-0.03657254  0.0262656 ]
# Episode_Number:98 TotalR: 35.000  Average_Reward: 58.040  len(H):5000.000  W:[-0.03085706  0.04141093]
# Episode_Number:99 TotalR: 10.000  Average_Reward: 58.140  len(H):5000.000  W:[-0.06532866  0.01889807]
# Episode_Number:100 TotalR:  9.000  Average_Reward: 58.140  len(H):5000.000  W:[-0.04953235  0.02518973]
# Episode_Number:101 TotalR: 10.000  Average_Reward: 58.140  len(H):5000.000  W:[-0.00509614  0.02496631]
# Episode_Number:102 TotalR:348.000  Average_Reward: 59.570  len(H):5000.000  W:[0.0448141  0.01143262]
# Episode_Number:103 TotalR: 51.000  Average_Reward: 58.490  len(H):5000.000  W:[-0.0558212   0.02812271]
# Episode_Number:104 TotalR:  8.000  Average_Reward: 58.490  len(H):5000.000  W:[ 0.01974486 -0.02494164]
# Episode_Number:105 TotalR:500.000  Average_Reward: 61.800  len(H):5000.000  W:[ 0.01974486 -0.02494164]
# Episode_Number:106 TotalR:356.000  Average_Reward: 64.540  len(H):5000.000  W:[-0.03605527  0.02925894]
# Episode_Number:107 TotalR:  9.000  Average_Reward: 64.520  len(H):5000.000  W:[-0.0173389 -0.0368861]
# Episode_Number:108 TotalR: 10.000  Average_Reward: 64.530  len(H):5000.000  W:[-0.01526282  0.04123882]
